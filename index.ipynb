# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox as mb
win=tk.Tk()
win.title("🛠 PATRA")
win.geometry("600x700+50+50")
win.configure(bg="orange")
win.resizable(0,0)
#adding notebooks
nb=ttk.Notebook(win)
page1=tk.Frame(nb,height=700, width=600,bg="dark grey",borderwidth=2,relief="sunken")
page2=tk.Frame(nb,height=700, width=600,bg="Khaki",borderwidth=2,relief="sunken")
page3=tk.Frame(nb,height=700, width=600,bg="DarkKhaki",borderwidth=2,relief="sunken")
page4=tk.Frame(nb,height=700, width=600,bg="antiquewhite",borderwidth=2,relief="sunken")
nb.add(page1, text="✍️ COMPOSE")
nb.add(page2, text="🐒 INBOX")
nb.add(page3, text="SEND 🐝 MESSAGE")
nb.add(page4, text="☠︎ HISTORY")
nb.pack()
# page 1 design
# top label
A_1=tk.Label(page1,text="Compose ✍️ The Mail",bg="red",fg="white",height=1,width=80,font=("Verdana",20))
A_1.pack(pady=2)
def click(*args):#s
    a=sa.get()
    if a=="Sender's Address":
        e_1.delete(0, 'end')
        e_1.configure(highlightbackground="orange")
def click2(*args): #r
    b=ra.get()
    if b=="Reciever's Address":
        e_2.delete(0, 'end')
        e_2.configure(highlightbackground="orange")
def click3(*args): #SUB
    c=sub.get()
    if c=="Subject":
        e_3.delete(0, 'end')
        e_3.configure(highlightbackground="orange")
def click4(*args): #mssg
    d=e_4.get(1.0,"end-1c")
    if d=="Type Your ✏️ Message Here":
        e_4.delete(1.0, 'end')
        e_4.configure(highlightbackground="orange")
# sender
sa=tk.StringVar()
e_1=tk.Entry(page1,textvariable=sa,justify="center",highlightbackground="green",relief="raised",width=30,font=("Verdana",12))
e_1.pack(pady=10)
e_1.insert(0,"Sender's Address")
e_1.bind("<Button-1>", click)
# reciver
ra=tk.StringVar()
e_2=tk.Entry(page1,textvariable=ra,justify="center",highlightbackground="green",width=30,font=("Verdana",12))
e_2.pack()
e_2.insert(0,"Reciever's Address")
e_2.bind("<Button-1>", click2)
#subject
sub=tk.StringVar()
e_3=tk.Entry(page1,textvariable=sub,justify="center",highlightbackground="green",width=60,font=("Verdana",12))
e_3.pack(pady=25)
e_3.insert(0,"Subject")
e_3.bind("<Button-1>", click3)
#reset
def reset():
    a=sa.get()
    if a!="Sender's Address":
        e_1.delete(0, 'end')
        e_1.insert(0,"Sender's Address")
        e_1.configure(highlightbackground="green")
    b=ra.get()
    if b!="Reciever's Address":
        e_2.delete(0, 'end')
        e_2.insert(0,"Reciever's Address")
        e_2.configure(highlightbackground="green")
    c=sub.get()
    if c!="Subject":
        e_3.delete(0, 'end')
        e_3.insert(0,"Subject")
        e_3.configure(highlightbackground="green")
    d=e_4.get(1.0,"end-1c")
    if d!="Type Your ✏️ Message Here":
        e_4.delete(1.0, 'end')
        e_4.insert(1.0,"Type Your ✏️ Message Here")
        e_4.configure(highlightbackground="green")
b_1=tk.Button(page1,text="🎬",relief="raised",width=2,bg="red",fg="white",command=reset)
b_1.place(x=480,y=165)
#message
e_4=tk.Text(page1,highlightbackground="green",yscrollcommand="enable",width=65,font=("Verdana",12))
e_4.pack(pady=9)
e_4.insert(1.0,"Type Your ✏️ Message Here")
e_4.bind("<Button-1>", click4)
#send button
def send():
    a=sa.get()
    b=ra.get()
    c=sub.get()
    d=e_4.get(1.0,"end-1c")
    if a=="" or b=="" or c=="" or d=="" or a=="Sender's Address" or b=="Reciever's Address":
        mb.showinfo("🙏🏻 REQUEST","please fill 🖊  all DETAILS".title())
    else: 
        try:
            import smtplib as s
            ob=s.SMTP('smtp.gmail.com',587)
            ob.starttls()
            password="Shubh2018@4662"
            ob.login("pandeykedarnath18200@gmail.com",password)
            print("success")
            subject=c
            body="hyuggyh"
            message=f"subject: {subject} \n\n {body}"
            ob.sendmail(a,b,message)
        except Exception as e:
                mb.showerror("⚠️ ERROR",f"{e}\n\t\t\tor\nCHECK YOUR INTERNET CONNECTiON".title())    
        else:
            mb.showinfo("SUCCESS 👍🏾 BOX","sent 👍🏾 successfully".title())
            reset()
b_1=tk.Button(page1,text="👍🏾 SEND",relief="raised",highlightbackground="red",width=20,height=2,bg="grey",fg="red",font=("Verdana",22),command=send)
b_1.pack(pady=7)
win.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox as mb
#log in setup
win_login=tk.Tk()
win_login.title("LOG 🛠 IN")
win_login.configure(bg="orange")
win_login.resizable(0,0)
win_login.geometry("700x300+40+40")
#click
def click5(*args):#lsa
    e=lsa.get()
    if e=="enter your email".title():
        e_5.delete(0, 'end')
        e_5.configure(highlightbackground="orange")
def click6(*args): #pss
    f=pss.get()
    if f=="Password":
        e_6.delete(0, 'end')
        e_6.configure(highlightbackground="orange",show="*")
#label
A_1=tk.Label(win_login,text="LOG-IN 🙏🏻 Page",bg="red",fg="white",height=1,width=80,font=("Verdana",20))
A_1.pack(pady=2)
# sender
lsa=tk.StringVar()
e_5=tk.Entry(win_login,textvariable=lsa,justify="center",highlightbackground="green",relief="raised",width=30,font=("Verdana",12))
e_5.place(x=30,y=130)
e_5.insert(0,"enter your email".title())
e_5.bind("<Button-1>", click5)
# password
pss=tk.StringVar()
e_6=tk.Entry(win_login,textvariable=pss,justify="center",highlightbackground="green",width=30,font=("Verdana",12))
e_6.place(x=400,y=130)
e_6.insert(0,"Password")
e_6.bind("<Button-1>", click6)
def reset1():
    e=lsa.get()
    if e!="enter your email".title():
        e_5.delete(0, 'end')
        e_5.insert(0,"enter your email".title())
        e_5.configure(highlightbackground="green")
    f=pss.get()
    if f!="Password":
        e_6.delete(0, 'end')
        e_6.insert(0,"Password")
        e_5.configure(highlightbackground="green")
#login button
def login():
    e=lsa.get()
    f=pss.get()
    if e=="" or f=="" or e=="enter your email".title() or f=="Password":
        mb.showinfo("🙏🏻 REQUEST","please fill 🖊  all DETAILS".title())
    else: 
        try:
            pass
        except Exception as e:
                mb.showerror("⚠️ ERROR",f"{e}\n\t\t\tor\nCHECK YOUR INTERNET CONNECTiON".title())    
        else:
            mb.showinfo("SUCCESS 👍🏾 BOX","log-in success".title())
            reset1()
b_2=tk.Button(win_login,text="Log-In",relief="raised",highlightbackground="red",width=20,height=2,bg="grey",fg="red",font=("Verdana",22),command=login)
b_2.place(x=180,y=200)
win_login.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox as mb
from tkinter import filedialog as fd
from tkinter import *
#log in setup
win_login=tk.Tk()
win_login.title("LOG 🛠 IN")
win_login.configure(bg="orange")
win_login.resizable(0,0)
win_login.geometry("700x300+40+40")
#click
def click5(*args):#lsa
    e=lsa.get()
    if e=="enter your email".title():
        e_5.delete(0, 'end')
        e_5.configure(highlightbackground="orange")
def click6(*args): #pss
    f=pss.get()
    if f=="Password":
        e_6.delete(0, 'end')
        e_6.configure(highlightbackground="orange",show="*")
#label
A_1=tk.Label(win_login,text="LOG-IN 🙏🏻 Page",bg="red",fg="white",height=1,width=80,font=("Verdana",20))
A_1.pack(pady=2)
# sender
lsa=tk.StringVar()
e_5=tk.Entry(win_login,textvariable=lsa,justify="center",highlightbackground="green",relief="raised",width=30,font=("Verdana",12))
e_5.place(x=30,y=130)
e_5.insert(0,"enter your email".title())
e_5.bind("<Button-1>", click5)
# password
pss=tk.StringVar()
e_6=tk.Entry(win_login,textvariable=pss,justify="center",highlightbackground="green",width=30,font=("Verdana",12))
e_6.place(x=400,y=130)
e_6.insert(0,"Password")
e_6.bind("<Button-1>", click6)
def reset1():
    e=lsa.get()
    if e!="enter your email".title():
        e_5.delete(0, 'end')
        e_5.insert(0,"enter your email".title())
        e_5.configure(highlightbackground="green")
    f=pss.get()
    if f!="Password":
        e_6.delete(0, 'end')
        e_6.insert(0,"Password")
        e_5.configure(highlightbackground="green")
#login button
def login():
    e=lsa.get()
    f=pss.get()
    if e=="" or f=="" or e=="enter your email".title() or f=="Password":
        mb.showinfo("🙏🏻 REQUEST","please fill 🖊  all DETAILS".title())
    else: 
        try:
            #############
            mb.showinfo("SUCCESS 👍🏾 BOX","log-in success".title())
            reset1()
            win=tk.Toplevel(win_login)
            win.title("🛠 PATRA")
            win.geometry("600x700+50+50")
            win.configure(bg="orange")
            win.resizable(0,0)
            #adding notebooks
            nb=ttk.Notebook(win)
            page1=tk.Frame(nb,height=700, width=600,bg="dark grey",borderwidth=2,relief="sunken")
            page2=tk.Frame(nb,height=700, width=600,bg="Khaki",borderwidth=2,relief="sunken")
            page3=tk.Frame(nb,height=700, width=600,bg="DarkKhaki",borderwidth=2,relief="sunken")
            page4=tk.Frame(nb,height=700, width=600,bg="antiquewhite",borderwidth=2,relief="sunken")
            nb.add(page1, text="✍️ COMPOSE")
            nb.add(page2, text="🐒 INBOX")
            nb.add(page3, text="SEND 🐝 MESSAGE")
            nb.add(page4, text="☠︎ HISTORY")
            nb.pack()
            # page 1 design
            # top label
            A_1=tk.Label(page1,text="Compose ✍️ The Mail",bg="red",fg="white",height=1,width=80,font=("Verdana",20))
            A_1.pack(pady=2)
            #SETTING BUTTON
            def setting():
                win_s=tk.Toplevel(win_login)
                win_s.title("ROUGH WORK")
                win_s.geometry("320x350+650+650")
                win_s.configure(bg="grey")
                #rough
                e_7=tk.Text(win_s,highlightbackground="green",yscrollcommand="enable",width=320,height=350,font=("Verdana",12))
                e_7.pack()
                win_s.resizable(0,0)
            b_5=tk.Button(page1,text="⚔️",relief="raised",width=2,bg="red",fg="white",command=setting)
            b_5.place(x=10,y=165)
            def click(*args):#s
                a=sa.get()
                if a=="Sender's Address":
                    e_1.delete(0, 'end')
                    e_1.configure(highlightbackground="orange")
            def click2(*args): #r
                b=ra.get()
                if b=="Reciever's Address":
                    e_2.delete(0, 'end')
                    e_2.configure(highlightbackground="orange")
            def click3(*args): #SUB
                c=sub.get()
                if c=="Subject":
                    e_3.delete(0, 'end')
                    e_3.configure(highlightbackground="orange")
            def click4(*args): #mssg
                d=e_4.get(1.0,"end-1c")
                if d=="Type Your ✏️ Message Here":
                    e_4.delete(1.0, 'end')
                    e_4.configure(highlightbackground="orange")
            # sender
            sa=tk.StringVar()
            e_1=tk.Entry(page1,textvariable=sa,justify="center",highlightbackground="green",relief="raised",width=30,font=("Verdana",12))
            e_1.pack(pady=10)
            e_1.insert(0,"Sender's Address")
            e_1.bind("<Button-1>", click)
            # reciver
            ra=tk.StringVar()
            e_2=tk.Entry(page1,textvariable=ra,justify="center",highlightbackground="green",width=30,font=("Verdana",12))
            e_2.pack()
            e_2.insert(0,"Reciever's Address")
            e_2.bind("<Button-1>", click2)
            #subject
            sub=tk.StringVar()
            e_3=tk.Entry(page1,textvariable=sub,justify="center",highlightbackground="green",width=60,font=("Verdana",12))
            e_3.pack(pady=25)
            e_3.insert(0,"Subject")
            e_3.bind("<Button-1>", click3)
            #reset
            def reset():
                a=sa.get()
                if a!="Sender's Address":
                    e_1.delete(0, 'end')
                    e_1.insert(0,"Sender's Address")
                    e_1.configure(highlightbackground="green")
                b=ra.get()
                if b!="Reciever's Address":
                    e_2.delete(0, 'end')
                    e_2.insert(0,"Reciever's Address")
                    e_2.configure(highlightbackground="green")
                c=sub.get()
                if c!="Subject":
                    e_3.delete(0, 'end')
                    e_3.insert(0,"Subject")
                    e_3.configure(highlightbackground="green")
                d=e_4.get(1.0,"end-1c")
                if d!="Type Your ✏️ Message Here":
                    e_4.delete(1.0, 'end')
                    e_4.insert(1.0,"Type Your ✏️ Message Here")
                    e_4.configure(highlightbackground="green")
            b_4=tk.Button(page1,text="🎬",relief="raised",width=2,bg="red",fg="white",command=reset)
            b_4.place(x=480,y=165)
            #message
            e_4=tk.Text(page1,highlightbackground="green",yscrollcommand="enable",width=65,font=("Verdana",12))
            e_4.pack(pady=9)
            e_4.insert(1.0,"Type Your ✏️ Message Here")
            e_4.bind("<Button-1>", click4)
            #send button
            def send():
                a=sa.get()
                b=ra.get()
                c=sub.get()
                d=e_4.get(1.0,"end-1c")
                if a=="" or b=="" or c=="" or d=="" or a=="Sender's Address" or b=="Reciever's Address":
                    mb.showinfo("🙏🏻 REQUEST","please fill 🖊  all DETAILS".title())
                else: 
                    try:
                        import smtplib as s
                        ob=s.SMTP('smtp.gmail.com',587)
                        ob.starttls()
                        password="Shubh2018@4662"
                        ob.login("pandeykedarnath18200@gmail.com",password)
                        print("success")
                        subject=c
                        body=d
                        message=f"subject: {subject} \n\n {body}"
                        ob.sendmail(a,b,message)
                        print(d)
                    except Exception as e:
                        mb.showerror("⚠️ ERROR",f"{e}\n\t\t\tor\nCHECK YOUR INTERNET CONNECTiON".title())    
                    else:
                        mb.showinfo("SUCCESS 👍🏾 BOX","sent 👍🏾 successfully".title())
                        
                        reset()
            def doc():
                filepath=fd.askopenfilename()
                imagedoc=PhotoImage(file=filepath)
                e_4.insert(1.0,imagedoc)
            b_3=tk.Button(page1,text="UPLOAD DOC.",relief="raised",highlightbackground="red",width=15,height=1,bg="grey",fg="red",font=("Verdana",22),command=doc)
            b_3.place(x=5,y=580)
            b_1=tk.Button(page1,text="👍🏾 SEND",relief="raised",highlightbackground="red",width=15,height=1,bg="grey",fg="red",font=("Verdana",22),command=send)
            b_1.place(x=290,y=580)
            win.mainloop()
            ##############
        except Exception as e:
                mb.showerror("⚠️ ERROR",f"{e}\n\t\t\tor\nCHECK YOUR INTERNET CONNECTiON".title())    
                reset1()
b_2=tk.Button(win_login,text="Log-In",relief="raised",highlightbackground="red",width=20,height=2,bg="grey",fg="red",font=("Verdana",22),command=login)
b_2.place(x=180,y=200)
win_login.mainloop()
